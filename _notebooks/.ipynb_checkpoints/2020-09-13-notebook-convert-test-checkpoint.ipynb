# %% [markdown]
# # Title
# > Awesom summary
# - toc: False

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.random.randn(12)

# %%
plt.plot(a);
plt.title("tests");

# %%
print('a')
# Out:
# a
